# %%
import os
import numpy as np
import pandas as pd
import scipy
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

import statsmodels.api as sm

# %%
data = pd.read_csv('data/csvs/v5_average_case_size9_count_1000_numtodo_70')

# %%
n = 60
ins = data['input'][:n]
times = data['time'][:n]

# %%
plt.plot(ins, times)

# %%
tmp = np.exp(0.0919636 * ins) -26.2447
plt.plot(ins, tmp, label='reg')
plt.plot(ins, times, label='time')
plt.legend()

# %%
l = np.log(times)

# %%
plt.plot(ins, l)

# %%
a = 0.00455577
b = -0.1537
c = -1.19915

# %%
ansthing = a * l * l + b * l + c

plt.plot(ins, l, label='time')
plt.plot(ins, ansthing, label='reg')
plt.legend()
